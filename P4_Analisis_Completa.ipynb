# %% [markdown]
# <a href="https://colab.research.google.com/github/JulTob/Data/blob/main/P4_Analisis_Completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 4

# %% [markdown]
# ## ⚠️ IMPORTANTE ⚠️
# - En el menú superior seleccionar: `Runtime` ⇒ `Change Runtime Type` ⇲ `Runtime Type`⇒ `R`

# %% [markdown]
# - Nota: Han cambiado la base de datos el 5 de Noviembre de 2025. He intentado actualizar mis procesos y conclusiones, pero puede haberse escapado algo.

# %% [markdown]
# Confirmamos que funcione R

# %%
R.version.string
# Out:
# [1] "R version 4.5.2 (2025-10-31)"

# %% [markdown]
# Para asegurar reproducibilidad se ha hosteado el archivo csv en GitHub.

# %%
install.packages("readr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(readr)
url <- "https://raw.githubusercontent.com/JulTob/Data/main/CSVs/temperatura.csv"
df <- read_delim(url, delim = ";")
head(df)
# Out:
# Rows: 23 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# chr (2): City, Area
# dbl (4): Annual, Amplitude, Latitude, Longitude
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   City        Annual Amplitude Latitude Longitude Area
# 1 Amsterdam    9.9   14.6      52.2      4.5      West
# 2 Athens      17.8   18.3      37.6     23.5      South
# 3 Berlin       9.1   18.5      52.3     13.2      West
# 4 Brussels    10.3   14.4      50.5      4.2      West
# 5 Budapest    10.9   23.1      47.3     19.0      East
# 6 Copenhagen   7.8   17.5      55.4     12.3      North

# %% [markdown]
# # Ejercicio 1:

# %%
install.packages("nasaweather")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nasaweather)
data(storms)
head(storms)
# Out:
#   name    year month day hour lat  long  pressure wind type
# 1 Allison 1995 6     3    0   17.4 -84.3 1005     30   Tropical Depression
# 2 Allison 1995 6     3    6   18.3 -84.9 1004     30   Tropical Depression
# 3 Allison 1995 6     3   12   19.3 -85.7 1003     35   Tropical Storm
# 4 Allison 1995 6     3   18   20.6 -85.8 1001     40   Tropical Storm
# 5 Allison 1995 6     4    0   22.0 -86.0  997     50   Tropical Storm
# 6 Allison 1995 6     4    6   23.3 -86.3  995     60   Tropical Storm
#   seasday category
# 1 3       -1
# 2 3       -1
# 3 3        0
# 4 3        0
# 5 4        0
# 6 4        0

# %%
# 1 mbar = 100 Pascales [Pa] = [N]/[m2]
# 1 nudo = 0.514444 metros por segundo (m/s)

storms_si <- storms
    #-- Storms con unidades del SI

storms_si$pressure_pa <- storms_si$pressure * 100
storms_si$wind_ms <- storms_si$wind * 0.514444

# Display
head(storms_si)
# Out:
#   name    year month day hour lat  long  pressure wind type
# 1 Allison 1995 6     3    0   17.4 -84.3 1005     30   Tropical Depression
# 2 Allison 1995 6     3    6   18.3 -84.9 1004     30   Tropical Depression
# 3 Allison 1995 6     3   12   19.3 -85.7 1003     35   Tropical Storm
# 4 Allison 1995 6     3   18   20.6 -85.8 1001     40   Tropical Storm
# 5 Allison 1995 6     4    0   22.0 -86.0  997     50   Tropical Storm
# 6 Allison 1995 6     4    6   23.3 -86.3  995     60   Tropical Storm
#   seasday category pressure_pa wind_ms
# 1 3       -1       100500      15.43332
# 2 3       -1       100400      15.43332
# 3 3        0       100300      18.00554
# 4 3        0       100100      20.57776
# 5 4        0        99700      25.72220
# 6 4        0        99500      30.86664

# %% [markdown]
# ### Media y Mediana

# %%
# Medidas centrales de tendencia
mean_wind_ms <- mean(storms_si$wind_ms)
median_wind_ms <- median(storms_si$wind_ms)

cat("Media de wind_ms:", mean_wind_ms, "\n")
cat("Mediana de wind_ms:", median_wind_ms, "\n")
# Out:
# Media de wind_ms: 28.13149
# Mediana de wind_ms: 25.7222

# %% [markdown]
# # Moda

# %% [markdown]
# Lo más natural es dividir el rango entre el máximo y mínimo valor, dividirlo en $Log(N)$ medidas (siendo N el Nº total de medidas). Se puede realizar el histograma de esta tabla, pero para obtener la moda swolo necesitamos el máximo.

# %% [markdown]
# Un detalle a considerar es el tamaño de la base del logaritmo. Como norma general, base 2 tiene ciertas propiedades de interés (entropia, digitalización...) pero sobretodo tiene la bondad de referirse a 'divisiones por la mitad'. Además de ser la representación más granular.

# %%
# Calculate the range of wind_ms
min_wind_ms <- min(storms_si$wind_ms, na.rm = TRUE)
max_wind_ms <- max(storms_si$wind_ms, na.rm = TRUE)

N <- length(storms_si$wind_ms)
num_divisions <- ceiling(log2(N))
    #-- Base 2 es la más detallada

bins <- seq(
    min_wind_ms,
    max_wind_ms,
    length.out = num_divisions)

wind_ms_binned <- cut(
    storms_si$wind_ms,
    breaks = bins,
    include.lowest = TRUE)

# Tabla de frecuencia
wind_ms_freq <- table(wind_ms_binned)

# La agrupación modal
mode_bin_index <- which.max(wind_ms_freq)
mode_bin <- names(mode_bin_index)


cat("Nº de Divisiones:", num_divisions, "\n")
head(wind_ms_freq)
cat("Tramo de Moda de wind_ms:", mode_bin, "\n")
# Out:
# Nº de Divisiones: 12
# wind_ms_binned
# [7.72,14.3] (14.3,20.8] (20.8,27.4] (27.4,33.9] (33.9,40.5]   (40.5,47]
#         293         791         436         479         255         231
# Tramo de Moda de wind_ms: (14.3,20.8]

# %% [markdown]
# Ahora podemos calcular la marca del intervalo (bin).

# %%
min_bin <- bins[mode_bin_index]
max_bin <- bins[mode_bin_index + 1]

cat("Min de la bin modal:", min_bin, "\n")
cat("Max de la bin modal:", max_bin, "\n")

mode_wind_ms = (min_bin + max_bin)/2
cat("Valor de marca de la moda:", mode_wind_ms)
# Out:
# Min de la bin modal: 14.26413
# Max de la bin modal: 20.8116
# Valor de marca de la moda: 17.53786

# %% [markdown]
# Podemos aprovechar la tabla para representar los datos.

# %%
hist(storms_si$wind_ms, breaks = bins, main = "Velocidad del Viento (m/s) con Medidas de Tendencia Central", xlab = "Velocidad del Viento (m/s)", ylab = "Frecuencia", col = "skyblue", border = "blue")

# Add vertical lines for mean, median, and mean within the modal bin
abline(v = mean_wind_ms, col = "blue", lty = 2, lwd = 2)
abline(v = median_wind_ms, col = "navy", lty = 2, lwd = 2)
abline(v = mode_wind_ms, col = "cyan", lty = 2, lwd = 2)

# Add a legend
legend("topright", legend = c("Mean", "Median", "Marca de Moda"), col = c("blue", "navy", "cyan"), lty = 2, lwd = 2)
# Out:
# Plot with title “Velocidad del Viento (m/s) con Medidas de Tendencia Central”

# %% [markdown]
# Vemos gracias al Log2 que se trata de una distribución más o menos Parettoide.

# %% [markdown]
# Yo particularmente entiendo mejor el uso de kmh que ms. Podemos convertir fácilmente estas medidas de tendencia para entender mejor estas medidas de tendencia. Esto nos ayudará a interpretar las medidas de manera más familiar.

# %%
# Conversion factor from m/s to km/h
ms_to_kmh <- 3.6

# Convert mean, median, and mean in modal bin to km/h
mean_wind_kmh <- mean_wind_ms * ms_to_kmh
median_wind_kmh <- median_wind_ms * ms_to_kmh
mode_wind_kmh <- mode_wind_ms * ms_to_kmh

# Display the results
cat("Velocidad media del viento (km/h):", mean_wind_kmh, "\n")
cat("Velocidad mediana del viento (km/h):", median_wind_kmh, "\n")
cat("Velocidad modal del viento (km/h):", mode_wind_kmh, "\n")
# Out:
# Velocidad media del viento (km/h): 101.2734
# Velocidad mediana del viento (km/h): 92.59992
# Velocidad modal del viento (km/h): 63.13631

# %% [markdown]
# Esto permite entender que de media el viento en una tormenta alcanza los 100 kilometros por hora de media, pero la observación más medida será de poco más de 60 kilometros por hora.
#
# Esto significa, por ejemplo, que el impacto por un objeto llevado por el viento es comparable a que se lancen desde un coche en carretera comarcal para el grueso de objetos, pero la mayoría sería equivalentes a que lo lance un coche en autovía. El efecto a la larga seria que cada objeto ha sido lanzado a una velocidad de autovia, de 100 kmh.
#
#  <!--< Se nota que trabajo en seguros? >-->

# %% [markdown]
# ### Calcula el primer y tercer cuartil e interpreta los resultados.

# %%
# Calculate the first and third quartiles of wind_ms
quartiles_wind_ms <- quantile(storms_si$wind_ms, probs = c(0.25, 0.75), na.rm = TRUE)

# Extract the first and third quartiles
q1_wind_ms <- quartiles_wind_ms[1]
q3_wind_ms <- quartiles_wind_ms[2]

cat("Primer Quartil (Q1) de wind_ms:", q1_wind_ms, "\n")
cat("Tercer Quartil (Q3) de wind_ms:", q3_wind_ms, "\n")
# Out:
# Primer Quartil (Q1) de wind_ms: 18.00554
# Tercer Quartil (Q3) de wind_ms: 36.01108

# %% [markdown]
# ### Calcula P5 y P80 en interpreta los resultados

# %%
# Calculate the 5th and 80th percentiles of wind_ms
percentiles_wind_ms <- quantile(storms_si$wind_ms, probs = c(0.05, 0.80), na.rm = TRUE)

# Extract the 5th and 80th percentiles
p5_wind_ms <- percentiles_wind_ms[1]
p80_wind_ms <- percentiles_wind_ms[2]

cat("5º Percentil (P5) de wind_ms:", p5_wind_ms, "\n")
cat("80º Percentil (P80) de wind_ms:", p80_wind_ms, "\n")
# Out:
# 5º Percentil (P5) de wind_ms: 12.8611
# 80º Percentil (P80) de wind_ms: 38.5833

# %% [markdown]
# ### d) Calcula el rango y el rango intercuartílico.

# %%
# Rango de wind_ms
range_wind_ms <- max(storms_si$wind_ms, na.rm = TRUE) - min(storms_si$wind_ms, na.rm = TRUE)

# Rango Interquartil(IQR) de wind_ms
# Ya tenemos Q1 y Q3
iqr_wind_ms <- q3_wind_ms - q1_wind_ms

cat("Rango de wind_ms:", range_wind_ms, "\n")
cat("Rango Interquartil (IQR) de wind_ms:", iqr_wind_ms, "\n")
# Out:
# Rango de wind_ms: 72.02216
# Rango Interquartil (IQR) de wind_ms: 18.00554

# %% [markdown]
# ### Calcula la desviación media y la desviación media respecto de la mediana.

# %%
# Calculate the Mean Absolute Deviation (deviation from the mean)
mad_mean_wind_ms <- mean(abs(storms_si$wind_ms - mean_wind_ms), na.rm = TRUE)

# Calculate the Mean Absolute Deviation from the Median
mad_median_wind_ms <- mean(abs(storms_si$wind_ms - median_wind_ms), na.rm = TRUE)

cat("Mean Absolute Deviation (from Mean) of wind_ms:", mad_mean_wind_ms, "\n")
cat("Mean Absolute Deviation (from Median) of wind_ms:", mad_median_wind_ms, "\n")
# Out:
# Mean Absolute Deviation (from Mean) of wind_ms: 10.76965
# Mean Absolute Deviation (from Median) of wind_ms: 10.51267

# %% [markdown]
# ### Calcula la varianza y desviación típica

# %%
# Calculate the variance of wind_ms
variance_wind_ms <- var(storms_si$wind_ms, na.rm = TRUE)

# Calculate the standard deviation of wind_ms
sd_wind_ms <- sd(storms_si$wind_ms, na.rm = TRUE)

cat("Variance of wind_ms:", variance_wind_ms, "\n")
cat("Standard Deviation of wind_ms:", sd_wind_ms, "\n")
# Out:
# Variance of wind_ms: 176.8262
# Standard Deviation of wind_ms: 13.2976

# %% [markdown]
# ### Calcula el coeficiente de variación de Pearson e Intercuartílico.
# ¿Los datos están muy
# dispersos?

# %%
# Calculate Pearson's Coefficient of Variation
# CV_Pearson = (Standard Deviation / Mean) * 100
cv_pearson <- (sd_wind_ms / mean_wind_ms) * 100

# Calculate the Interquartile Coefficient of Variation
# CV_IQR = ((Q3 - Q1) / (Q3 + Q1)) * 100
cv_iqr <- ((q3_wind_ms - q1_wind_ms) / (q3_wind_ms + q1_wind_ms)) * 100

cat("Pearson's Coefficient of Variation:", cv_pearson, "%\n")
cat("Interquartile Coefficient of Variation:", cv_iqr, "%\n")
# Out:
# Pearson's Coefficient of Variation: 47.26945 %
# Interquartile Coefficient of Variation: 33.33333 %

# %% [markdown]
# ### h) Valora la forma de la distribución de esta variable (asimetría y curtosis).

# %%
# Calculate skewness manually
n <- length(storms_si$wind_ms)
mean_wind_ms <- mean(storms_si$wind_ms, na.rm = TRUE)
sd_wind_ms <- sd(storms_si$wind_ms, na.rm = TRUE)

skewness_manual <- (1/n) * sum(((storms_si$wind_ms - mean_wind_ms) / sd_wind_ms)^3, na.rm = TRUE)

cat("Manual Skewness of wind_ms:", skewness_manual, "\n")
# Out:
# Manual Skewness of wind_ms: 0.8981482

# %%
# Calculate kurtosis (excess kurtosis) manually
n <- length(storms_si$wind_ms)
mean_wind_ms <- mean(storms_si$wind_ms, na.rm = TRUE)
sd_wind_ms <- sd(storms_si$wind_ms, na.rm = TRUE)

kurtosis_manual <- ((1/n) * sum(((storms_si$wind_ms - mean_wind_ms) / sd_wind_ms)^4, na.rm = TRUE)) - 3

cat("Manual Kurtosis (Excess) of wind_ms:", kurtosis_manual, "\n")
# Out:
# Manual Kurtosis (Excess) of wind_ms: 0.3246446

# %% [markdown]
# ### Realiza un histograma y el gráfico de cajas de la variable wind e interpreta los gráficos.

# %%
# Create a histogram of the 'wind' variable
hist(storms_si$wind_ms, main = "Histogram of Wind Speed (m/s)", xlab = "Wind Speed (m/s)", ylab = "Frequency", col = "skyblue", border = "black")
# Out:
# Plot with title “Histogram of Wind Speed (m/s)”

# %%
# Create a box plot of the 'wind' variable
boxplot(storms_si$wind_ms, main = "Box Plot of Wind Speed (m/s)", ylab = "Wind Speed (m/s)", col = "lightgrey", border = "black")
# Out:
# Plot with title “Box Plot of Wind Speed (m/s)”

# %% [markdown]
# A mí particularmente me gusta combinar el plot de Violín con el de caja. La información principal es transmitida por la caja, pero el violín nos aporta una visión de la forma de la distribución más directa.

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

ggplot(storms_si, aes(x = "", y = wind_ms)) +
    geom_violin(fill = "grey",
        alpha = 0.8,
        color = NA,
        linewidth = 0) +
    geom_boxplot(
        width = 0.5,
        fill = "grey",
        color = "black",
        alpha = 0.8) +
    labs(title = "Velocidad del Viento (m/s)",
       x = "",
       y = "Wind Speed (m/s)") +
  theme_minimal() +
  theme(
    plot.title = element_text(size = 14, face = "bold"),
    axis.title.y = element_text(size = 12),
    axis.text.y = element_text(size = 10)
    )
# Out:
# plot without title

# %% [markdown]
# - #### Media (28 m/s) y mediana (25 m/s):
#    - La media es ligeramente superior a la mediana.
#    - En una distribución perfectamente simétrica, la media y la mediana son iguales. Esta diferencia sugiere cierta asimetría en los datos, con la media tendiendo hacia valores más altos.
#
# - Asimetría (0,90):
#   - El valor positivo de asimetría confirma que la distribución presenta una asimetría positiva moderada.
#   - Esta cola hacia la derecha influye en la media, alejándola del centro de la mayor parte de los datos, que en una distribución asimétrica está mejor representado por la mediana.
#
# - ### Histograma y diagrama de caja
#   - Ambas visualizaciones muestran claramente una distribución asimétrica, con una cola más larga a la derecha y una concentración de datos a velocidades de viento más bajas.
#   - La línea mediana del diagrama de caja tampoco se encuentra en el centro exacto de la caja, y el bigote superior es más largo, lo que respalda visualmente la asimetría positiva.
#
# - Dada la asimetría positiva moderada de los datos de viento (wind_ms), es probable que la media (28 m/s) no sea la mejor representante de la velocidad típica del viento, en comparación con la mediana (25 m/s).
#
#   - La media es sensible a los valores extremos.
#   - La mediana, por otro lado, es una medida más robusta del centro para distribuciones asimétricas.
#
# - Por lo tanto, mientras que la media indica la velocidad promedio del viento, la mediana proporciona una mejor indicación del valor central que representa la mayoría de tormentas, ordenadas en dos mitades iguales.

# %%
head(storms_si)
# Out:
#   name    year month day hour lat  long  pressure wind type
# 1 Allison 1995 6     3    0   17.4 -84.3 1005     30   Tropical Depression
# 2 Allison 1995 6     3    6   18.3 -84.9 1004     30   Tropical Depression
# 3 Allison 1995 6     3   12   19.3 -85.7 1003     35   Tropical Storm
# 4 Allison 1995 6     3   18   20.6 -85.8 1001     40   Tropical Storm
# 5 Allison 1995 6     4    0   22.0 -86.0  997     50   Tropical Storm
# 6 Allison 1995 6     4    6   23.3 -86.3  995     60   Tropical Storm
#   seasday category pressure_pa wind_ms
# 1 3       -1       100500      15.43332
# 2 3       -1       100400      15.43332
# 3 3        0       100300      18.00554
# 4 3        0       100100      20.57776
# 5 4        0        99700      25.72220
# 6 4        0        99500      30.86664

# %% [markdown]
# ### Realiza un gráfico de cajas de la variable wind para cada tipo de tormenta.

# %% [markdown]
# Por lo visto a ratos

# %%
unique(storms_si$type)
# Out:
# [1] "Tropical Depression" "Tropical Storm"      "Hurricane"
# [4] "Extratropical"

# %%
unique(storms_si$status)
# Out:
# Warning message:
# “Unknown or uninitialised column: `status`.”
# NULL

# %%
unique(storms_si$category)
# Out:
# [1] -1  0  1  2  3  4  5

# %%
library(dplyr)
library(forcats) # For handling factors

# Define the mapping for renaming levels
type_recode_map <- c("Depresión Tropical" = "Tropical Depression",
                     "Tormenta Tropical" = "Tropical Storm",
                     "Huracán" = "Hurricane")

# Rename levels and handle NA values
storms_si <- storms_si %>%
  mutate(type = as.factor(type)) %>% # Ensure type is a factor
  mutate(type = fct_recode(type, !!!type_recode_map)) %>% # Recode existing levels
  mutate(type = fct_explicit_na(type, na_level = "Sin Clasificar")) # Handle NA values

# Print the updated unique levels to confirm changes
print(levels(storms_si$type))
head(storms_si)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following object is masked _by_ ‘.GlobalEnv’:
#
#     storms
#
#
# The following object is masked from ‘package:nasaweather’:
#
#     storms
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `type = fct_explicit_na(type, na_level = "Sin Clasificar")`.
# Caused by warning:
# ! `fct_explicit_na()` was deprecated in forcats 1.0.0.
# ℹ Please use `fct_na_value_to_level()` instead.”
# [1] "Extratropical"      "Huracán"            "Depresión Tropical"
# [4] "Tormenta Tropical"
#   name    year month day hour lat  long  pressure wind type
# 1 Allison 1995 6     3    0   17.4 -84.3 1005     30   Depresión Tropical
# 2 Allison 1995 6     3    6   18.3 -84.9 1004     30   Depresión Tropical
# 3 Allison 1995 6     3   12   19.3 -85.7 1003     35   Tormenta Tropical
# 4 Allison 1995 6     3   18   20.6 -85.8 1001     40   Tormenta Tropical
# 5 Allison 1995 6     4    0   22.0 -86.0  997     50   Tormenta Tropical
# 6 Allison 1995 6     4    6   23.3 -86.3  995     60   Tormenta Tropical
#   seasday category pressure_pa wind_ms
# 1 3       -1       100500      15.43332
# 2 3       -1       100400      15.43332
# 3 3        0       100300      18.00554
# 4 3        0       100100      20.57776
# 5 4        0        99700      25.72220
# 6 4        0        99500      30.86664

# %%
library(ggplot2)
library(dplyr)
library(forcats)

desired_order_spanish <- c("Depresión Tropical", "Tormenta Tropical", "Huracán", "Sin Clasificar")

# Explicitly handle NA values by replacing them with "Sin Clasificar" string
storms_si <- storms_si %>%
  mutate(type = if_else(is.na(type), "Sin Clasificar", type)) %>%
  # Now convert to factor with the desired order and levels
  mutate(type = factor(type, levels = desired_order_spanish))

# Define a gray-blue color palette including the color for "Sin Clasificar"
gray_blue_palette <- c(
    "Depresión Tropical" = "lightsteelblue",
    "Tormenta Tropical" = "cornflowerblue",
    "Huracán" = "royalblue",
    "Sin Clasificar" = "grey")

# Create combined box and violin plots of wind by storm type
ggplot(storms_si, aes(x = type, y = wind, fill = type)) +
  geom_violin(alpha = 0.75, color = NA, linewidth = 0, width = 2) + # Increase the width of violin plots
  geom_boxplot(width = 0.2, color = "black", alpha = 0.4) + # Keep the box plot width smaller
  scale_fill_manual(values = gray_blue_palette) + # Apply the gray-blue palette
  labs(title = "Velocidad del Viento (nudos) por Tipo de Tormenta (Ordenado por Intensidad)",
       x = "Tipo de Tormenta",
       y = "Velocidad del Viento (nudos)") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), # Rotate x-axis labels for readability
        legend.position = "none") # Remove the legend
# Out:
# Warning message:
# “`position_dodge()` requires non-overlapping x intervals.”
# plot without title
